# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat publications.tsv
# Out:
# pub_date	title	venue	excerpt	citation	url_slug	paper_url
# 2009-10-01	Paper Title Number 1	Journal 1	This paper is about the number 1. The number 2 is left for future work.	Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).	paper-title-number-1	http://academicpages.github.io/files/paper1.pdf
# 2010-10-01	Paper Title Number 2	Journal 1	This paper is about the number 2. The number 3 is left for future work.	Your Name, You. (2010). "Paper Title Number 2." <i>Journal 1</i>. 1(2).	paper-title-number-2	http://academicpages.github.io/files/paper2.pdf
# 2015-10-01	Paper Title Number 3	Journal 1	This paper is about the number 3. The number 4 is left for future work.	Your Name, You. (2015). "Paper Title Number 3." <i>Journal 1</i>. 1(3).	paper-title-number-3	http://academicpages.github.io/files/paper3.pdf

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("publications.tsv", sep="\t", header=0)
publications
# Out:
#      pub_date                 title      venue  \
# 0  2009-10-01  Paper Title Number 1  Journal 1
# 1  2010-10-01  Paper Title Number 2  Journal 1
# 2  2015-10-01  Paper Title Number 3  Journal 1
#
#                                              excerpt  \
# 0  This paper is about the number 1. The number 2...
# 1  This paper is about the number 2. The number 3...
# 2  This paper is about the number 3. The number 4...
#
#                                             citation              url_slug  \
# 0  Your Name, You. (2009). "Paper Title Number 1....  paper-title-number-1
# 1  Your Name, You. (2010). "Paper Title Number 2....  paper-title-number-2
# 2  Your Name, You. (2015). "Paper Title Number 3....  paper-title-number-3
#
#                                          paper_url
# 0  http://academicpages.github.io/files/paper1.pdf
# 1  http://academicpages.github.io/files/paper2.pdf
# 2  http://academicpages.github.io/files/paper3.pdf

# %%
publications = pd.read_csv("citations.tsv", sep=",", header=0)
publications
# Out:
#                                               Authors  \
# 0   Mann, Michael E; Rahmstorf, Stefan; Kornhuber,...
# 1   Petoukhov, Vladimir; Petri, Stefan; Kornhuber,...
# 2   Kornhuber, Kai; Kavalakkatt, Jaison; Lin, Xian...
# 3   Kornhuber, Kai; Osprey, Scott; Coumou, Dim; Pe...
# 4   Kornhuber, Kai; Petoukhov, Vladimir; Petri, St...
# 5   Mann, Michael E; Rahmstorf, Stefan; Kornhuber,...
# 6   Kornhuber, K; Petoukhov, V; Karoly, D; Petri, ...
# 7   Petoukhov, Vladimir; Petri, Stefan; Rahmstorf,...
# 8   Coumou, Dim; Kornhuber, Kai; Lehmann, Jascha; ...
# 9   Huntingford, Chris; Mitchell, Dann; Kornhuber,...
# 10  Mitchell, Dann; Kornhuber, Kai; Huntingford, C...
# 11  Pfleiderer, Peter; Schleussner, Carl-Friedrich...
# 12  Raymond, Colin; Coumou, Dim; Foreman, Tim; Kin...
# 13  Raymond, Colin; Horton, Radley M; Zscheischler...
# 14   Drouard, Marie; Kornhuber, Kai; Woollings, Tim;
# 15  Kornhuber, Kai; Coumou, Dim; Vogel, Elisabeth;...
#
#                                                 Title  \
# 0   Influence of anthropogenic climate change on p...
# 1   Alberta wildfire 2016: Apt contribution from a...
# 2   In situ monitoring of electrophoretic depositi...
# 3   Extreme weather events in early summer 2018 co...
# 4   Evidence for wave resonance as a key mechanism...
# 5   Projected changes in persistent extreme summer...
# 6   Summertime planetary wave resonance in the Nor...
# 7   Role of quasiresonant planetary wave dynamics ...
# 8   Weakened Flow, Persistent Circulation, and Pro...
# 9   Assessing changes in risk of amplified planeta...
# 10  The day the 2003 European heatwave record was ...
# 11  Summer weather becomes more persistent in a 2 ...
# 12     Projections and hazards of future extreme heat
# 13  Understanding and managing connected extreme e...
# 14  Disentangling dynamic contributions to summer ...
# 15  Amplified Rossby waves enhance risk of concurr...
#
#                                         Publication  Volume  Number  \
# 0                                Scientific Reports     7.0     NaN
# 1                                Scientific reports     8.0     1.0
# 2                                      RSC Advances     3.0    17.0
# 3                    Environmental Research Letters    14.0     5.0
# 4                                  Climate Dynamics    49.0     5.0
# 5                                  Science advances     4.0    10.0
# 6                                Journal of Climate    30.0    16.0
# 7   Proceedings of the National Academy of Sciences   113.0    25.0
# 8                                    Clim. Extremes   226.0     NaN
# 9                       Atmospheric Science Letters    20.0     8.0
# 10                      The Lancet Planetary Health     3.0     7.0
# 11                            Nature Climate Change     9.0     9.0
# 12              Planning for Climate Change Hazards     NaN     NaN
# 13                            Nature climate change    10.0     7.0
# 14                     Geophysical Research Letters    46.0    21.0
# 15                            Nature Climate Change    10.0     1.0
#
#           Pages  Year                                          Publisher
# 0         45242  2017                            Nature Publishing Group
# 1          1-10  2018                            Nature Publishing Group
# 2     5845-5850  2013                         Royal Society of Chemistry
# 3        054002  2019                                     IOP Publishing
# 4     1961-1979  2017                         Springer Berlin Heidelberg
# 5      eaat3272  2018  American Association for the Advancement of Sc...
# 6     6133-6150  2017                                                NaN
# 7     6862-6867  2016                             National Acad Sciences
# 8         61-73  2017                                                NaN
# 9          e929  2019             John Wiley & Sons, Ltd. Chichester, UK
# 10    e290-e292  2019                                           Elsevier
# 11      666-671  2019                            Nature Publishing Group
# 12          NaN  2019                            Oxford University Press
# 13      611-621  2020                            Nature Publishing Group
# 14  12537-12546  2019                               Wiley Online Library
# 15        48-53  2020                            Nature Publishing Group

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    
    md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
    html_filename = str(item.pub_date) + "-" + item.url_slug
    year = item.pub_date[:4]
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'
    
    md += """collection: publications"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.paper_url)) > 5:
        md += "\npaperurl: '" + item.paper_url + "'"
    
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item.excerpt)) > 5:
        md += "\n" + html_escape(item.excerpt) + "\n"
    
    if len(str(item.paper_url)) > 5:
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
        
    md += "\nRecommended citation: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-592da968cbd3> in <module>
#       2 for row, item in publications.iterrows():
#       3
# ----> 4     md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
#       5     html_filename = str(item.pub_date) + "-" + item.url_slug
#       6     year = item.pub_date[:4]
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'pub_date'

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
# 2009-10-01-paper-title-number-1.md 2015-10-01-paper-title-number-3.md
# 2010-10-01-paper-title-number-2.md

# %%
# !cat ../_publications/2009-10-01-paper-title-number-1.md
# Out:
# ---
# title: "Paper Title Number 1"
# collection: publications
# permalink: /publication/2009-10-01-paper-title-number-1
# excerpt: 'This paper is about the number 1. The number 2 is left for future work.'
# date: 2009-10-01
# venue: 'Journal 1'
# paperurl: 'http://academicpages.github.io/files/paper1.pdf'
# citation: 'Your Name, You. (2009). &quot;Paper Title Number 1.&quot; <i>Journal 1</i>. 1(1).'
# ---
# This paper is about the number 1. The number 2 is left for future work.
#
# [Download paper here](http://academicpages.github.io/files/paper1.pdf)
#
# Recommended citation: Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).
